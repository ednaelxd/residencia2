# %%
import pandas as pd
import numpy as np
import glob
from src.feature_engeneering._00_import_merge import importa_dados_zip
from src.feature_engeneering.generate_data import generate_1

# %% [markdown]
# # Base de Licitações

# %%
from base64 import decode


path = r'C:\Users\efvs\Documents\Residencia Ednael\Dados licitações\nnn\lic' # use your path
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = importa_dados_zip(filename)
    li.append(df)

frame = pd.concat(li, axis=0, ignore_index=True)

# %%
frame.head()
# Out:
#    Código UG                                      Nome UG  \
# 0     344002                      FUNDACAO JOAQUIM NABUCO
# 1     753000  INSTITUTO DE EST. DO MAR ALTE PAULO MOREIRA
# 2     110099  SUPERINTENDENCIA ADMINISTRACAO EM SAO PAULO
# 3     110591              FUNDO NACIONAL DE AVIACAO CIVIL
# 4     114617            UNIDADE ESTADUAL DO IBGE NA BAHIA
#
#    Código Modalidade Compra             Modalidade Compra    Número Processo  \
# 0                        20                      Concurso       0235/2019-30
# 1                         3                  Concorrência  63432000786202057
# 2                         7  Inexigibilidade de Licitação  00589001437202130
# 3                         7  Inexigibilidade de Licitação  50000028940202093
# 4                         7  Inexigibilidade de Licitação       208817772102
#
#                                               Objeto  \
# 0  Objeto: A Fundação Joaquim Nabuco (Fundaj), Fu...
# ...

# %%
frame.to_csv('dados_lic_2.csv')

# %%
df = generate_1(r'C:\Users\efvs\Documents\Residencia Ednael\Repositórios\residencia2\data\dados_lic_2.csv',r'C:\Users\efvs\Documents\Residencia Ednael\Repositórios\cidades.csv')
# Out:
# url_data = C:\Users\efvs\Documents\Residencia Ednael\Repositórios\cidades.csv
# url_cidades = C:\Users\efvs\Documents\Residencia Ednael\Repositórios\cidades.csv
# . . . . . Importando dados lict . . . . .
#
# . . . . . . .Adc Coluna Obras . . . . . .
#
# . . . . . . .TAGUIANDO . . . . . .
#
# . . . .  . Adicionando Cidades. . . . . .

# %%
df.to_csv("df_geral_2.csv")

# %%
df_o = pd.read_csv(r'C:\Users\efvs\Documents\Residencia Ednael\Repositórios\residencia2\data\lic_taguiado.csv', index_col=[0])

# %%
df = pd.read_csv(r'C:\Users\efvs\Documents\Residencia Ednael\Repositórios\residencia2\data\df_geral_2.csv', index_col=[0])

# %%
df.rename({'UF_y':'UF'},axis=1,inplace=True)

# %%
df.drop('UF_x',axis=1,inplace=True)

# %%
df_recorte = df_o[df_o['data']>='2020-09']

# %%
del(df_recorte['Número Licitação'])

# %%
dd = pd.concat([df_recorte,df], axis=0, ignore_index=True)

# %%
del(dd['Data Abertura'])
df.rename({'Valor Licitação':'Total'},axis=1,inplace=True)

# %%
print(df_recorte.shape)
print(df.shape)
print(dd.shape)
# Out:
# (27848, 18)
# (14957, 18)
# (42805, 17)

# %%
df.head()
# Out:
#     Código UG                                        Nome UG  \
# 4      250029             SUPERINTENDENCIA ESTADUAL DO MS/PE
# 6      373048   SUPERINTENDENCIA REG. DE PERNAMBUCO - SR(PE)
# 9      255017                FUNDACAO NACIONAL DE SAUDE - PE
# 11     160185                          14 BATALHAO LOGISTICO
# 12     160193  CMDO 10ª BDA INF MTZ - CONTROLE PATM E CUSTOS
#
#     Código Modalidade Compra           Modalidade Compra    Número Processo  \
# 4                          5                      Pregão  25019.002322/2021
# 6                          5                      Pregão  54000171070201999
# 9                          5                      Pregão  25225001073202148
# 11                       -99  Pregão - Registro de Preço  64132005606202151
# 12                       -99  Pregão - Registro de Preço  64304003879202142
#
#                                                Objeto  \
# 4   Objeto: Pregão Eletrônico -  Contratação de em...
# ...

# %%
dd.to_csv('df_ATT.csv')

# %%
# regras de associação ECLAT, APRIORI

# %% [markdown]
# # Base de Itens

# %%
from base64 import decode


path = 'C:\\Users\\efvs\\Documents\\Residencia Ednael\\Dados licitações\\2020_09.2022_05\\itens' # use your path
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, encoding='latin',index_col=[0], sep=';')
    li.append(df)

frame2 = pd.concat(li, axis=0, ignore_index=True)

# %%
frame2.head()
# Out:
#    Código UG                                    Nome UG  \
# 0     158274  INST.FED. FLUMINENSE/CAMPUS CAMPOS-CENTRO
# 1     158274  INST.FED. FLUMINENSE/CAMPUS CAMPOS-CENTRO
# 2     158274  INST.FED. FLUMINENSE/CAMPUS CAMPOS-CENTRO
# 3     158274  INST.FED. FLUMINENSE/CAMPUS CAMPOS-CENTRO
# 4     158274  INST.FED. FLUMINENSE/CAMPUS CAMPOS-CENTRO
#
#    Código Modalidade Compra Modalidade Compra    Número Processo  \
# 0                         5            Pregão  23318000158201920
# 1                         5            Pregão  23318000158201920
# 2                         5            Pregão  23318000158201920
# 3                         5            Pregão  23318000158201920
# 4                         5            Pregão  23318000158201920
#
#    Código Órgão                    Nome Órgão      Código Item Compra  \
# 0         26434  Instituto Federal Fluminense  1582740500001201900001
# 1         26434  Instituto Federal Fluminense  1582740500001201900002
# ...

# %%
frame2.rename({'Valor Item':'valor_item'},axis=1,inplace=True)

# %%
frame2.to_csv('dados_itens_2.csv')
