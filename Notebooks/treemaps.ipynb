# %%
import pandas as pd
import numpy as np
dd = pd.read_csv('C:/Users/efvs/Documents/Residencia Ednael/Repositórios/residencia2/data/lic_taguiado.csv', index_col=[0])

# %%
dd1=dd[dd['Tag']==1]

# %%
dd2=dd[dd['Tag']==0]

# %% [markdown]
# ## TREEMAP GERAL DOS VALORES FRAUDADOS

# %%
list(pd.Series(dd2['UF'].unique()))
# Out:
# ['AM',
#  'MG',
#  'AL',
#  'MS',
#  'SE',
#  'BA',
#  'AC',
#  'RO',
#  'RJ',
#  'RS',
#  'RN',
#  'RR',
#  'PB',
#  'PR',
#  'SP',
#  'CE',
#  'MT',
#  'TO',
#  'PI',
#  'SC',
#  'PE',
#  'GO',
#  'MA',
#  'ES',
#  'AP',
#  'PA']

# %%
dd2['UF'].unique()[:2]
# Out:
# array(['AM', 'MG'], dtype=object)

# %%
len(dd2)
# Out:
# 40815

# %%
dd2['Objeto'].values[1][28:]
# Out:
# ' Registro de preços para eventual aquisição de material de consumo e permanente de manobra e patrulhamento para atender as necessidades do Comando Militar da Amazônia e Órgãos Participantes.'

# %%
fig.data[0].
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24932/3028276666.py in <module>
# ----> 1 fig.data[0].uniformtext_minsize[10]
#
# AttributeError: 'Treemap' object has no attribute 'uniformtext_minsize'

# %%
px.choropleth(dd2,locations='UF',color='Total')

# %%
gp1=dd2[['UF','Objeto','Total']].groupby(['UF','Objeto'], as_index=False).value_counts()

# %%
cont=0
for line in gp1['Objeto'][0:20]:
    gp1['Objeto'][cont] = line[0:30] +'<br>'+line[30:]
    cont+=1
# Out:
# C:\Users\efvs\AppData\Local\Temp/ipykernel_18548/2404006094.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
fig = px.treemap(gp1[0:20],path=['UF','Objeto']
                ,maxdepth=3)
fig.data[0].texttemplate = "%{label}"
fig.data[0]['textfont']['size']=13
fig.show()
# Out:
# c:\Users\efvs\miniconda3\envs\rsd\lib\site-packages\plotly\express\_core.py:1637: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# c:\Users\efvs\miniconda3\envs\rsd\lib\site-packages\plotly\express\_core.py:1637: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %%
import plotly.express as px

dd3=dd2['Total']/1000000

fig = px.treemap(dict(dd2),path=[px.Constant('Estados'),dd2['UF'],'Nome Órgão Superior'],
                 values=dd3,maxdepth=3)
 #           values='Total de Licitações')
fig.update_layout(uniformtext_minsize=18)
fig.update_traces(root_color="lightgray",textfont_color='rgb(255,255,255)')

fig.update_layout(
    title_text='Itens por Estado-Órgão, em licitações Irregulares',title_x=0.5
)
fig.update_layout(margin = dict(t=35, l=25, r=25, b=25))
fig.data[0].customdata = dd3
fig.data[0].texttemplate = "%{label}<br>Totais: R$%{value:.2f}M"
fig.data[0]['textfont']['size']=13
fig.show()
# Out:
# c:\Users\efvs\miniconda3\envs\rsd\lib\site-packages\plotly\express\_core.py:1637: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# c:\Users\efvs\miniconda3\envs\rsd\lib\site-packages\plotly\express\_core.py:1637: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# c:\Users\efvs\miniconda3\envs\rsd\lib\site-packages\plotly\express\_core.py:1637: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %%
fig.data[0]
# Out:
# Treemap({
#     'branchvalues': 'total',
#     'customdata': array([[ 28272.  ,   9628.  , 225045.73, ...,  24444.3 ,  76727.  ,  27516.93]]),
#     'domain': {'x': [0.0, 1.0], 'y': [0.0, 1.0]},
#     'hovertemplate': 'labels=%{label}<br>Total=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>',
#     'ids': array(['Estados/AC/Advocacia-Geral da União',
#                   'Estados/MG/Advocacia-Geral da União',
#                   'Estados/PE/Advocacia-Geral da União', ..., 'Estados/SP', 'Estados/TO',
#                   'Estados'], dtype=object),
#     'labels': array(['Advocacia-Geral da União', 'Advocacia-Geral da União',
#                      'Advocacia-Geral da União', ..., 'SP', 'TO', 'Estados'], dtype=object),
#     'name': '',
#     'parents': array(['Estados/AC', 'Estados/MG', 'Estados/PE', ..., 'Estados', 'Estados', ''],
#                      dtype=object),
#     'root': {'color': 'lightgrey'},
#     'textfont': {'color': 'rgb(255,255,255)'},
# ...

# %%
levels = ['salesperson', 'county', 'region']

# %%
print(enumerate(levels))

# %% [markdown]
# ## TREEMAP DAS PCTS ACIMA

# %%
dd2=dd[(dd['Tag']==0) & (dd['Total']!=0)]
from src.feature_engeneering._03_plus_times_total import calcula_pct_teto

abc = pd.DataFrame(calcula_pct_teto(dd2))
dd2['pct_do_teto']=abc[0].values
#dd2.loc[:,'pct_do_teto']=abc[0].values
# Out:
# C:\Users\efvs\AppData\Local\Temp/ipykernel_4520/3670549256.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dd2['pct_do_teto']=abc[0].values

# %%
resum1=dd2.groupby(['UF']).agg({'pct_do_teto':['sum','count','mean','max']})['pct_do_teto']
resum1.reset_index()
resum1=resum1.reset_index()
resum1['mean']=resum1['mean'].round(2)
resum1.sort_values(by='mean',ascending=False)
# Out:
#     UF        sum  count  mean       max
# 2   AM  61.643655    889  0.07  1.827423
# 9   MG  27.034841    572  0.05  1.836136
# 10  MS  19.378561    419  0.05  2.102210
# 1   AL  16.056314    419  0.04  2.363021
# 0   AC   0.000000      0   NaN       NaN
# 3   AP   0.000000      0   NaN       NaN
# 4   BA   0.000000      0   NaN       NaN
# 5   CE   0.000000      0   NaN       NaN
# 6   ES   0.000000      0   NaN       NaN
# 7   GO   0.000000      0   NaN       NaN
# 8   MA   0.000000      0   NaN       NaN
# 11  MT   0.000000      0   NaN       NaN
# 12  PA   0.000000      0   NaN       NaN
# 13  PB   0.000000      0   NaN       NaN
# 14  PE   0.000000      0   NaN       NaN
# 15  PI   0.000000      0   NaN       NaN
# 16  PR   0.000000      0   NaN       NaN
# 17  RJ   0.000000      0   NaN       NaN
# 18  RN   0.000000      0   NaN       NaN
# 19  RO   0.000000      0   NaN       NaN
# 20  RR   0.000000      0   NaN       NaN
# 21  RS   0.000000      0   NaN       NaN
# ...

# %%
dd3=dd2[dd2['Tag']==0]
dd3=dd3.sort_values(by='pct_do_teto',ascending=False)

# %%
dd3['Objeto']
# Out:
# 311562    Objeto: Pregão Eletrônico -  Execução dos serv...
# 351715    Objeto: Pregão Eletrônico -  Contratação de se...
# 351716    Objeto: Pregão Eletrônico -  Contratação de se...
# 351776    Objeto: Pregão Eletrônico -  Execução dos serv...
# 311561    Objeto: Pregão Eletrônico -  Execução dos serv...
#                                 ...
# 33225     Objeto: Pregão Eletrônico -  Contratação de se...
# 13591     Objeto: Pregão Eletrônico -  Registro de Preço...
# 185535    Objeto: Pregão Eletrônico -  Contratação de em...
# 233981    Objeto: Pregão Eletrônico -  Cessão de Uso de ...
# 130588    Objeto: Pregão Eletrônico -  Contratação de se...
# Name: Objeto, Length: 32782, dtype: object

# %%
import plotly.express as px

dd3=dd3.sort_values(by='pct_do_teto',ascending=False)

fig = px.bar(dd3[0:20],x=('Número Processo'),
                 y='pct_do_teto',hover_data=['Município','Nome Órgão Superior','Objeto'],color='UF')
 #           values='Total de Licitações')
fig.update_layout(uniformtext_minsize=14)
#fig.update_traces(root_color="lightgrey")
fig.update_layout(
    title_text='Top 10: Licitações que mais ultrapassam o teto estabelecido pro Lei'
)
fig.show()

# %% [markdown]
# ### TOP 10 EM PLUS_TIMES_TOTAL

# %%
dd2['pct_do_teto'].max()
# Out:
# 2.3630210227272728

# %%
#dd2.drop(['Código Modalidade Compra','Situação Licitação','Código Órgão','Data Abertura'],axis=1)
(dd2.drop(['Código Modalidade Compra','Situação Licitação','Código Órgão','Data Abertura'],axis=1)).iloc[:, 2:].sort_values(by='pct_do_teto',ascending=False)[0:10]
# Out:
#                                               Nome UG  \
# 311562  CIA DE DES.DOS VALES DO S.FRANC.E DO PARNAIBA
# 351715  CIA DE DES.DOS VALES DO S.FRANC.E DO PARNAIBA
# 351716  CIA DE DES.DOS VALES DO S.FRANC.E DO PARNAIBA
# 351776  CIA DE DES.DOS VALES DO S.FRANC.E DO PARNAIBA
# 311561  CIA DE DES.DOS VALES DO S.FRANC.E DO PARNAIBA
# 217617             UNIVERSIDADE FEDERAL DE PERNAMBUCO
# 42015         CG DE MATERIAL E PATRIMONIO - CGMAP/SAA
# 130584                               COLEGIO PEDRO II
# 77078    COORDENACAO GERAL DE LICITACOES E CONTRATOS.
# 52311         DEPARTAMENTO DE ENGENHARIA E CONSTRUCAO
#
#                  Modalidade Compra    Número Processo  \
# 311562  Pregão - Registro de Preço  59520001453202089
# 351715  Pregão - Registro de Preço  59560001216202041
# 351716  Pregão - Registro de Preço  59560001333202013
# 351776  Pregão - Registro de Preço  59560001156202067
# 311561  Pregão - Registro de Preço  59520001452202034
# ...

# %% [markdown]
# # TRYING TO USE GO TREEMAP

# %% [markdown]
# ### INITIALIZING

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/sales_success.csv')
print(df.head())
# Out:
#    Unnamed: 0 region   county salesperson  calls  sales
# 0           0  North   Dallam          JE     35     23
# 1           1  North   Dallam          ZQ     49     13
# 2           2  North   Dallam          IJ     20      6
# 3           3  North  Hartley          WE     39     37
# 4           4  North  Hartley          PL     42     37

# %% [markdown]
# ### PREPARATION

# %%
levels = ['salesperson', 'county', 'region'] # levels used for the hierarchical chart
color_columns = ['sales', 'calls']
value_column = 'calls'

# %% [markdown]
# ### CRIANDO DF HIERARQUICO

# %%
def build_hierarchical_dataframe(df, levels, value_column, color_columns=None):
    """
    Build a hierarchy of levels for Sunburst or Treemap charts.

    Levels are given starting from the bottom to the top of the hierarchy,
    ie the last level corresponds to the root.
    """
    df_h = pd.DataFrame(columns=['id', 'parent', 'value', 'color'])
    for i, level in enumerate(levels):
        df_tree = pd.DataFrame(columns=['id', 'parent', 'value', 'color'])
        dfg = df.groupby(levels[i:]).sum()
        dfg = dfg.reset_index()
        df_tree['id'] = dfg[level].copy()
        if i < len(levels) - 1:
            df_tree['parent'] = dfg[levels[i+1]].copy()
        else:
            df_tree['parent'] = 'total'
        df_tree['value'] = dfg[value_column]
        df_tree['color'] = dfg[color_columns[0]] / dfg[color_columns[1]]
        df_h = df_h.append(df_tree, ignore_index=True)
    total = pd.Series(dict(id='total', parent='',
                              value=df[value_column].sum(),
                              color=df[color_columns[0]].sum() / df[color_columns[1]].sum()))
    df_all_trees = df_all_trees.append(total, ignore_index=True)
    return df_all_trees

# %%
df_all_trees = build_hierarchical_dataframe(df, levels, value_column, color_columns)
# Out:
# C:\Users\efvs\AppData\Local\Temp/ipykernel_24932/2588856700.py:20: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\efvs\AppData\Local\Temp/ipykernel_24932/2588856700.py:20: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\efvs\AppData\Local\Temp/ipykernel_24932/2588856700.py:20: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\efvs\AppData\Local\Temp/ipykernel_24932/2588856700.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %%
df_all_trees
# Out:
#        id    parent value     color
# 0      AX   Houston    42  0.214286
# 1      BI   Hartley    24  0.333333
# 2      BS  Brewster    33  0.424242
# 3      DQ  Presidio    40     0.375
# 4      DS     Duval    42  0.214286
# ..    ...       ...   ...       ...
# 68   East     total   407   0.39312
# 69  North     total   631  0.605388
# 70  South     total   381  0.506562
# 71   West     total   321  0.588785
# 72  total            1740  0.531034
#
# [73 rows x 4 columns]

# %%
levels = ['salesperson', 'county', 'region'] # levels used for the hierarchical chart
color_columns = ['sales', 'calls']
value_column = 'calls'

# %%
levels = ['Objeto','Nome Órgão Superior'] # levels used for the hierarchical chart
color_columns = ['Total','Total']
value_column = 'Total'

# %%
df_h = build_hierarchical_dataframe(dd2.head(100), levels, value_column, color_columns)
# Out:
# C:\Users\efvs\AppData\Local\Temp/ipykernel_24932/2588856700.py:20: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\efvs\AppData\Local\Temp/ipykernel_24932/2588856700.py:20: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\efvs\AppData\Local\Temp/ipykernel_24932/2588856700.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %%
np.arange(0,78365)
# Out:
# array([    0,     1,     2, ..., 78362, 78363, 78364])

# %%
df_h['color']=np.arange(0,78366)

# %%
df_h
# Out:
#                                                   id                parent  \
# 0  Objeto: Pregão Eletrônico -  Contratação de se...  Ministério da Defesa
# 1  Objeto: Pregão Eletrônico -  Registro de preço...  Ministério da Defesa
# 2  Objeto: Pregão Eletrônico -  Registro de preço...  Ministério da Defesa
# 3  Objeto: Pregão Eletrônico -  Registro de preço...  Ministério da Defesa
# 4  Objeto: Pregão Eletrônico -  Serviço de manute...  Ministério da Defesa
# 5                               Ministério da Defesa                 total
# 6                                              total
#
#        value color
# 0   37317.57   1.0
# 1     9628.0   1.0
# 2  225045.73   1.0
# 3        0.0   NaN
# 4    28272.0   1.0
# 5   300263.3   1.0
# 6   300263.3   1.0

# %%
fig = make_subplots(1, 1, specs=[[{"type": "domain"}]])#, {"type": "domain"}]],)

fig.add_trace(go.Treemap(
    labels=df_h['id'],
    parents=df_h['parent'],
    values=df_h['value'],
    branchvalues='total', maxdepth=3,
    #hovertemplate='<b>%{label} </b> <br> Sales: %{value}<br> Success rate: %{color:.2f}',
    name=''
    ), 1, 1)

'''fig.add_trace(go.Treemap(
    labels=df_h['id'],
    parents=df_h['parent'],
    values=df_h['value'],
    branchvalues='total',
    #hovertemplate='<b>%{label} </b> <br> Sales: %{value}<br> Success rate: %{color:.2f}',
    maxdepth=2
    ), 1, 2)'''

#fig.update_layout(margin = dict(t=50, l=25, r=25, b=25))
fig.data[0]['textfont']['size']=12
fig.show()
