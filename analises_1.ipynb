# %%
import pandas as pd

# %%
from src.generate_data import generate_1

df = generate_1('C:\\Users\\efvs\\Documents\\Residencia Ednael\\Repositórios\\data_all.zip','C:\\Users\\efvs\\Documents\\Residencia Ednael\\Repositórios\\cidades.csv')
# Out:
# url_data = C:\Users\efvs\Documents\Residencia Ednael\Repositórios\cidades.csv
# url_cidades = C:\Users\efvs\Documents\Residencia Ednael\Repositórios\cidades.csv
# . . . . . Importando dados lict . . . . .
#
# . . . . . . .Adc Coluna Obras . . . . . .
#
# . . . . . . .TAGUIANDO . . . . . .
#
# . . . .  . Adicionando Cidades. . . . . .

# %%
df.groupby(['UF']).agg({'Total':'sum','UF':'count'})

# %%
pd.options.display.float_format = '{:,.4f}'.format

from src.reports_functions.fraudes_estados import indice_fraude_estado
fraudes = indice_fraude_estado(df,'2018','2020')
fraudes
# Out:
# Para o perído de 2018 à 2020
#     {%} de Ilegalidades  Total de Licitações  Total de Ilegais  \
# GO               0.6958                  240               167
# MT               0.6948                  403               280
# PB               0.6783                 1057               717
# RN               0.6671                 1694              1130
# RR               0.6528                  504               329
# ES               0.5911                  291               172
# BA               0.5860                 1785              1046
# RO               0.5839                  644               376
# AP               0.5750                   40                23
# MS               0.5657                 1483               839
# RS               0.5538                 3696              2047
# PI               0.5534                  842               466
# AM               0.5327                 1254               668
# MA               0.5290                  138                73
# SC               0.5192                  391               203
# AL               0.5119                 1047               536
# TO               0.5016                  305               153
# SE               0.4864                  627               305
# PR               0.4778                 3022              1444
# MG               0.4239                 4393              1862
# PE               0.4036                 2641              1066
# CE               0.3870                 1504               582
# RJ               0.3296                12780              4212
# AC               0.3011                 6148              1851
# PA               0.2876                  532               153
# SP               0.2711                 1863               505
#
#            Valor Licitado     Valor Ilegal  {%} Valor Ilegal
# GO        32,453,700.0900  19,787,980.3600            0.6097
# MT       926,836,304.3100  29,669,353.1100            0.0320
# PB       510,851,616.5100  71,552,023.5800            0.1401
# RN       590,802,355.6000 126,281,858.8900            0.2137
# RR       401,105,658.6100  54,685,881.2300            0.1363
# ES        48,566,583.1400  11,894,638.8600            0.2449
# BA     1,656,192,822.2000 271,957,835.4400            0.1642
# RO       571,148,597.4900  21,871,528.3600            0.0383
# AP         2,358,454.8200   1,414,054.0000            0.5996
# MS       749,185,416.0200  59,364,134.2800            0.0792
# RS     2,509,244,565.0200 194,335,705.2700            0.0774
# PI       905,343,347.8000  56,098,574.0100            0.0620
# AM     1,725,935,402.4000  78,383,229.2400            0.0454
# MA        12,095,345.1700   5,512,819.7300            0.4558
# SC       104,812,356.5000  16,086,559.7300            0.1535
# AL       789,432,939.7300  48,248,474.3000            0.0611
# TO       471,920,972.7500  18,425,586.4100            0.0390
# SE    22,736,188,562.4000  40,503,017.4300            0.0018
# PR     1,332,462,250.2800 115,748,160.1900            0.0869
# MG     1,913,880,595.2000 160,055,761.3400            0.0836
# PE     3,249,519,325.0400 136,068,729.2800            0.0419
# CE     1,816,121,013.8900  59,523,002.4300            0.0328
# RJ     9,458,140,620.6200 654,575,161.9200            0.0692
# AC 1,182,798,788,321.4700 443,493,664.4100            0.0004
# PA       114,414,666.8200  10,035,538.6200            0.0877
# SP       173,454,988.4800  45,662,767.9000            0.2633

# %%
from src.feature_engeneering._03_plus_times_total import calcula_pct_teto
pcts_teto = calcula_pct_teto(df.iloc[:,:-1])

# %%
df_0['Modalidade Compra'].value_counts()
# Out:
# Pregão - Registro de Preço    39902
# Dispensa de Licitação           913
# Name: Modalidade Compra, dtype: int64

# %%
print(pd.DataFrame(pcts_teto).shape)
print(pd.DataFrame(pcts_teto).value_counts())
# Out:
# (39613, 1)
# 0.0000    7903
# 0.0210      77
# 0.0084      55
# 0.0006      54
# 0.0420      53
#           ...
# 0.0104       1
# 0.0104       1
# 0.0104       1
# 0.0104       1
# 2.8409       1
# Length: 18623, dtype: int64

# %%
df.iloc[:,:-1].head(1)
# Out:
#    Número Licitação  Código UG                     Nome UG  \
# 1             32018     788810  ESTACAO NAVAL DO RIO NEGRO
#
#    Código Modalidade Compra           Modalidade Compra    Número Processo  \
# 1                       -99  Pregão - Registro de Preço  63160.000202/2018
#
#                                               Objeto  \
# 1  Objeto: Pregão Eletrônico -  Serviço de manute...
#
#               Situação Licitação  Código Órgão Superior   Nome Órgão Superior  \
# 1  Evento de Alteração Publicado                  52000  Ministério da Defesa
#
#    Código Órgão          Nome Órgão Município       data Data Abertura  \
# 1         52131  Comando da Marinha    MANAUS 2018-07-17    29/05/2018
#
#         Total Obras Tag
# 1 28,272.0000  Obra   0

# %%
df_0 = df[df['Tag']==0]
df_0.shape
# Out:
# (40815, 19)

# %%
df.groupby(['Modalidade Compra','Tag']).count()
