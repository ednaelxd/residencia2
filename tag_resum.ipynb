# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np

# %%
from functions.feature_engeneering._00_import_merge import importa_dados_zip, importa_dados_participantes, merge_dados_taguiados
# Out:
# . . . . . Importando dados . . . . .

# %%
city = pd.read_csv('C:\\Users\\efvs\\Documents\\Residencia Ednael\\Repositórios\\cidades.csv')

# %%
df = importa_dados_zip('C:\\Users\\efvs\\Documents\\Residencia Ednael\\Repositórios\\data_all.zip')
df_part = importa_dados_participantes('C:\\Users\\efvs\\Documents\\Residencia Ednael\\Repositórios\\dados_participantes.zip')

# %%
merge1 = merge_dados_taguiados(df,df_part,('Número Processo','Número Licitação'))

# %%
merge1.head()
# Out:
#    Número Licitação  Código UG                                        Nome UG  \
# 2             12018     153036  UNIVERSIDADE FED.VALES JEQUITINHONHA E MUCURI
# 3             12018     153036  UNIVERSIDADE FED.VALES JEQUITINHONHA E MUCURI
# 4             12018     153036  UNIVERSIDADE FED.VALES JEQUITINHONHA E MUCURI
# 5             12018     153036  UNIVERSIDADE FED.VALES JEQUITINHONHA E MUCURI
# 6             12018     153036  UNIVERSIDADE FED.VALES JEQUITINHONHA E MUCURI
#
#    Código Modalidade Compra           Modalidade Compra    Número Processo  \
# 2                       -99  Pregão - Registro de Preço  23086000649201861
# 3                       -99  Pregão - Registro de Preço  23086000649201861
# 4                       -99  Pregão - Registro de Preço  23086000649201861
# 5                       -99  Pregão - Registro de Preço  23086000649201861
# 6                       -99  Pregão - Registro de Preço  23086000649201861
#
#                                               Objeto  \
# 2  Objeto: Pregão Eletrônico -  Sistema de Regist...
# 3  Objeto: Pregão Eletrônico -  Sistema de Regist...
# 4  Objeto: Pregão Eletrônico -  Sistema de Regist...
# 5  Objeto: Pregão Eletrônico -  Sistema de Regist...
# 6  Objeto: Pregão Eletrônico -  Sistema de Regist...
#
#               Situação Licitação  Código Órgão Superior  \
# 2  Evento de Suspensão Publicado                  26000
# 3  Evento de Suspensão Publicado                  26000
# 4  Evento de Suspensão Publicado                  26000
# 5  Evento de Suspensão Publicado                  26000
# 6  Evento de Suspensão Publicado                  26000
#
#       Nome Órgão Superior  Código Órgão  \
# 2  Ministério da Educação         26255
# 3  Ministério da Educação         26255
# 4  Ministério da Educação         26255
# 5  Ministério da Educação         26255
# 6  Ministério da Educação         26255
#
#                                       Nome Órgão   Município        data  \
# 2  Universidade Federal dos Vales do Jequitinhon  DIAMANTINA  12/07/2018
# 3  Universidade Federal dos Vales do Jequitinhon  DIAMANTINA  12/07/2018
# 4  Universidade Federal dos Vales do Jequitinhon  DIAMANTINA  12/07/2018
# 5  Universidade Federal dos Vales do Jequitinhon  DIAMANTINA  12/07/2018
# 6  Universidade Federal dos Vales do Jequitinhon  DIAMANTINA  12/07/2018
#
#   Data Abertura   Total                          Descrição Item Compra  \
# 2    19/06/2018  714.57  MANUTENCAO / INSTALACOES PREDIAIS ELETRONICAS
# 3    19/06/2018  714.57  MANUTENCAO / INSTALACOES PREDIAIS ELETRONICAS
# 4    19/06/2018  714.57  MANUTENCAO / INSTALACOES PREDIAIS ELETRONICAS
# 5    19/06/2018  714.57  MANUTENCAO / INSTALACOES PREDIAIS ELETRONICAS
# 6    19/06/2018  714.57  MANUTENCAO / INSTALACOES PREDIAIS ELETRONICAS
#
#   CNPJ Participante                           Nome Participante Flag Vencedor
# 2    05202938000108                HC COMUNICACAO DE DADOS LTDA           NÃO
# 3    04503070000113          DINIZ TECNOLOGIA E SOLUCOES EIRELI           NÃO
# 4    00960027000126            BLINK TECNOLOGIA SOB MEDIDA LTDA           NÃO
# 5    05437291000101  MAXIMA NET TECNOLOGIA E CONSTRUCOES EIRELI           NÃO
# 6    73442360000117                       TELTEX TECNOLOGIA S/A           NÃO

# %%
df_final = merge_dados_taguiados(merge1,city,('Município'))
