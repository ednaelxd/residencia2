# %%
import pandas as pd

# %%
lic=pd.read_csv(r"C:\Users\efvs\Documents\Residencia Ednael\Dados licitações\202101_Licitação.csv", encoding='latin-1',sep=';',decimal=',')

# %%
lic.head()
# Out:
#    Número Licitação  Código UG                                      Nome UG  \
# 0             12019     154628      INST.FEDERAL FARROUPILHA CAMPUS JAGUARI
# 1             12020     927843  SECRETARIA DE EST.DE PLANEJ.E ADMINISTRAÇÃO
# 2             12020     925538         SECRETARIA DE ESTADO DA ADMINSTRAÇÃO
# 3             12020     925445     COMPANHIA DE HABITAÇÃO DO ESTADO DO PARÁ
# 4             12020     926418       COMPANHIA DE SERVIÇOS URBANOS DE NATAL
#
#    Código Modalidade Compra           Modalidade Compra    Número Processo  \
# 0                         2            Tomada de Preços  26420000767201908
# 1                       -99  Pregão - Registro de Preço        2019/204734
# 2                         5                      Pregão  00230040002019-37
# 3                         5                      Pregão        2020/348464
# 4                         5                      Pregão        20200215742
#
#                                               Objeto  \
# ...

# %%
lic['Modalidade Compra'].value_counts()
# Out:
# Dispensa de Licitação               1372
# Pregão - Registro de Preço          1115
# Pregão                               892
# Inexigibilidade de Licitação         635
# Tomada de Preços                      11
# Concorrência                           3
# Convite                                1
# Concurso                               1
# Concorrência - Registro de Preço       1
# Name: Modalidade Compra, dtype: int64

# %% [markdown]
# # Quais modalidades mais praticadas? Quem mais usa cada uma?

# %% [markdown]
# '''Na realidade o registro de preços é um PROCEDIMENTO especial de licitação que se efetiva utilizando-se as modalidades de licitações de Concorrência Pública e Pregão (eletrônico ou presencial), o qual seleciona a proposta mais vantajosa com observância fiel do princípio da isonomia, pois sua compra é projetada para uma futura contratação. A Administração Pública firma um compromisso por meio de uma ATA DE REGISTRO DE PREÇOS, onde se precisar de determinado produto registrado, o Licitante Vencedor estará obrigado ao fornecimento dentro do prazo de validade da referida ATA. O prazo de validade da Ata de Registro de Preço não poderá ser superior a um ano, computadas neste as eventuais prorrogações. Regulamentado pelo Decreto Nº 3.931, de 19 de Setembro de 2001.'''

# %%
lic_RP=lic[lic['Modalidade Compra']=='Pregão - Registro de Preço']

# %%
lic_RP['Nome Órgão'].value_counts()
# Out:
# Comando do Exército                             154
# Empresa Brasileira de Serviços Hospitalares     146
# Comando da Marinha                               62
# Comando da Aeronáutica                           55
# DISTRITO FEDERAL                                 50
#                                                ...
# ESTADO DA BAHIA                                   1
# Empresa Brasil de Comunicação                     1
# CONS. REG. DE ENFERMAGEM  MATO GROSSO DO SUL      1
# ESTADO DO PIAUI                                   1
# EMPRESAS DE ENERGIA                               1
# Name: Nome Órgão, Length: 135, dtype: int64

# %%
lic_Pregao=lic[lic['Modalidade Compra']=='Pregão']

# %%
lic_Pregao['Nome Órgão'].value_counts()
# Out:
# Empresas de Energia                             58
# ESTADO DE MINAS GERAIS                          54
# DISTRITO FEDERAL                                45
# ESTADO DO PARA                                  43
# ESTADO DE SAO PAULO                             37
#                                                 ..
# CONSELHO REGIONAL DE PSICOLOGIA DA 4ª REGIÃO     1
# ESTADO DO MATO GROSSO DO SUL                     1
# Agência Nacional de Transportes Aquaviários      1
# Instituto Federal do Triângulo Mineiro           1
# Instituto Federal do Pará                        1
# Name: Nome Órgão, Length: 160, dtype: int64

# %% [markdown]
# '''A Dispensa de Licitação é uma forma legal de contratação pelo governo que dispensa o uso de licitação. No entanto, ela só pode ser adotada quando for permitida por lei, em 35 hipóteses definidas na Lei 8.666/93.'''

# %%
lic_Dispensa=lic[lic['Modalidade Compra']=='Dispensa de Licitação']

# %%
lic_Dispensa['Nome Órgão'].value_counts()
# Out:
# Comando do Exército                              229
# Empresa Brasileira de Serviços Hospitalares      141
# Ministério da Economia - Unidades com vínculo     75
# Ministério da Saúde - Unidades com vínculo di     66
# Comando da Marinha                                41
#                                                 ...
# Instituto Nacional de Tecnologia da Informaçã      1
# Instituto Federal do Mato Grosso do Sul            1
# Instituto Federal da Bahia                         1
# Universidade Federal Rural do Semi-Árido           1
# ESTADO DO RIO GRANDE DO NORTE                      1
# Name: Nome Órgão, Length: 136, dtype: int64

# %% [markdown]
# A inexigibilidade de licitação se caracteriza pela impossibilidade de competição. Está determinada no art. 25 da Lei de Licitações e Contratos. Essa inviabilidade pode ser tanto pela exclusividade do objeto a ser contratado, como pela falta de empresas concorrentes.

# %%
lic_INEX=lic[lic['Modalidade Compra']=='Inexigibilidade de Licitação']

# %%
lic_INEX['Nome Órgão'].value_counts()
# Out:
# Comando do Exército                              161
# Comando da Marinha                                84
# Instituto Federal do Espírito Santo               36
# Comando da Aeronáutica                            24
# Empresa Brasileira de Serviços Hospitalares       20
#                                                 ...
# Instituto do Patrimônio Histórico e Artístico      1
# Universidade Federal de Alfenas                    1
# Fundação Casa de Rui Barbosa                       1
# Agência Nacional de Transportes Terrestres         1
# Conselho Administrativo de Defesa Econômica        1
# Name: Nome Órgão, Length: 93, dtype: int64

# %% [markdown]
# # Qual o valor médio das compras, por tipo de processo licitatório?

# %%
valores=pd.DataFrame()
valores['Nomes']=['Dispensa','Inex','Pregão','RP']
valores['Valor Médio']=[lic_Dispensa['Valor Licitação'].mean(),
lic_INEX['Valor Licitação'].mean(),
lic_Pregao['Valor Licitação'].mean(),
lic_RP['Valor Licitação'].mean()]

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
lic['Valor Licitação'].sum()
# Out:
# 3123046237.2

# %%
valores
# Out:
#       Nomes   Valor Médio
# 0  Dispensa  259632.08005
# 1      Inex 1364805.37022
# 2    Pregão 1556603.38102
# 3        RP  436072.74549

# %%
valores.sort_values('Valor Médio',ascending=False)
# Out:
#       Nomes   Valor Médio
# 2    Pregão 1556603.38102
# 1      Inex 1364805.37022
# 3        RP  436072.74549
# 0  Dispensa  259632.08005

# %% [markdown]
# # Quais órgãos são responsáveis pelos maiores gastos?

# %%
pd.set_option('display.max_rows', 500)

# %% [markdown]
# ### Gasto médio

# %%
lic.groupby(['Nome Órgão']).agg({'Valor Licitação':'mean'}).sort_values('Valor Licitação',ascending=False)
# Out:
#                                                Valor Licitação
# Nome Órgão
# Instituto Nacional de Estudos e Pesquisas Edu   63869024.86000
# Instituto Nacional da Propriedade Industrial    36418320.00000
# Empresa de Processamento de Dados da Previdên   15559720.59750
# Tribunal de Contas da União - Unidades com ví   10510574.66000
# Ministério da Justiça e Segurança Pública - U    5691781.28000
# Departamento Nacional de Infraestrutura de Tr    5227665.09542
# Ministério da Cidadania - Unidades com víncul    4589338.60000
# Companhia de Desenvolvimento dos Vales do São    4073941.90837
# Fundação Universidade Federal de Uberlândia      3854270.84000
# Companhia Docas do Espírito Santo                3446751.93000
# Ministério da Economia - Unidades com vínculo    3195857.10678
# Universidade Federal de Lavras                   3090475.59500
# Comissão Nacional de Energia Nuclear             2984807.77600
# ESTADO DO RIO GRANDE DO NORTE                    2838688.70886
# ...

# %% [markdown]
# ### Gasto máximo

# %%
lic.groupby(['Nome Órgão']).agg({'Valor Licitação':'max'}).sort_values('Valor Licitação',ascending=False).style.format("{:,.0f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_01934_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Valor Licitação</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Nome Órgão</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_01934_level0_row0" class="row_heading level0 row0" >Ministério da Economia - Unidades com vínculo</th>
#       <td id="T_01934_row0_col0" class="data row0 col0" >341,871,720</td>
#     </tr>
#     <tr>
#       <th id="T_01934_level0_row1" class="row_heading level0 row1" >Comando do Exército</th>
#       <td id="T_01934_row1_col0" class="data row1 col0" >117,538,143</td>
#     </tr>
#     <tr>
#       <th id="T_01934_level0_row2" class="row_heading level0 row2" >Instituto Nacional de Estudos e Pesquisas Edu</th>
#       <td id="T_01934_row2_col0" class="data row2 col0" >117,008,222</td>
#     </tr>
#     <tr>
# ...

# %%
lic['Município'].value_counts()
# Out:
# Inválido                        822
# RIO DE JANEIRO                  463
# BRASILIA                        347
# RECIFE                          123
# PORTO ALEGRE                    115
# CURITIBA                         99
# BELO HORIZONTE                   99
# SAO PAULO                        94
# FORTALEZA                        85
# SALVADOR                         68
# GOIANIA                          67
# BELEM                            65
# MANAUS                           64
# NITEROI                          63
# FLORIANOPOLIS                    59
# PELOTAS                          49
# NATAL                            49
# SANTA MARIA                      47
# CAMPO GRANDE                     39
# VITORIA                          39
# SAO LUIS                         39
# ITAJUBA                          38
# ITAJAI                           35
# TERESINA                         33
# CUIABA                           33
# JOAO PESSOA                      30
# ...

# %% [markdown]
# # Quais os objetos mais comprados?

# %%
from matplotlib import pyplot as plt

# %%
lic['Objeto'].value_counts().bar.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16568/1276466658.py in <module>
# ----> 1 lic['Objeto'].value_counts().bar.plot()
#
# ~\miniconda3\envs\rsd\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'bar'

# %%
# !pip install squarify

# %%
import squarify

# %%
plt.figure(figsize=(15,10))
squarify.plot(label=obj['index'][0:6],sizes=obj['Objeto'][0:6], alpha=.8)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(15,5))
plt.bar(obj['index'][0:6],obj['Objeto'][0:6])
plt.xticks(rotation=60,ha='right')
# Out:
# ([0, 1, 2, 3, 4, 5],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
obj=pd.DataFrame(lic['Objeto'].value_counts())

# %%
obj.reset_index(inplace=True)

# %%
obj.head()
# Out:
#                                                index  Objeto
# 0  Informação protegida\n por sigilo nos termos d...      59
# 1  Objeto: Credenciamento de ORGANIZAÇÕES CIVIS D...      28
# 2  Objeto: Credenciamento de Organizações Civis d...       7
# 3  Objeto: Aquisição de material(is) para  o  CMD...       6
# 4  Objeto: Prestação de serviços de assistência m...       5

# %%
obj['index'][0]='Informação protegida\n por sigilo nos termos da\n legislação vigente'
# Out:
# C:\Users\efvs\AppData\Local\Temp/ipykernel_16568/2468987339.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obj['index'][0]='Informação protegida\n por sigilo nos termos da\n legislação vigente'

# %%
obj['index'][1]='Objeto: Credenciamento de ORGANIZAÇÕES CIVIS DE SAÚDE (OCS)\n E DE PROFISSIONAIS DE SAÚDE AUTÔNOMOS (PSA) PARA PRESTAÇÃO\n DE SERVIÇOS MÉDICO-HOSPITALARES,ODONTOLÓGICOS E\n DE REABILITAÇÃO, conforme autorizado pelo art. 20 e seus incisos I e II,\n do Decreto Nr 92.512, de 2 de abril de 1.986;'
# Out:
# C:\Users\efvs\AppData\Local\Temp/ipykernel_16568/3669458734.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obj['index'][1]='Objeto: Credenciamento de ORGANIZAÇÕES CIVIS DE SAÚDE (OCS)\n E DE PROFISSIONAIS DE SAÚDE AUTÔNOMOS (PSA) PARA PRESTAÇÃO\n DE SERVIÇOS MÉDICO-HOSPITALARES,ODONTOLÓGICOS E\n DE REABILITAÇÃO, conforme autorizado pelo art. 20 e seus incisos I e II,\n do Decreto Nr 92.512, de 2 de abril de 1.986;'

# %%
obj['index'][2]='Objeto: Credenciamento de Organizações Civis de Saúde (OCS)\n e Profissionais de Saúde Autônomo (PSA) interessadas\n na prestação de serviços complementares de assistência\n médico-hospitalar, ambulatorial, atendimento de emergência/urgência em\n regime de 24 (vinte e quatro) horas diárias,\n atenção domiciliar, odontológica e de reabilitação.'
# Out:
# C:\Users\efvs\AppData\Local\Temp/ipykernel_16568/3857842987.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obj['index'][2]='Objeto: Credenciamento de Organizações Civis de Saúde (OCS)\n e Profissionais de Saúde Autônomo (PSA) interessadas\n na prestação de serviços complementares de assistência\n médico-hospitalar, ambulatorial, atendimento de emergência/urgência em\n regime de 24 (vinte e quatro) horas diárias,\n atenção domiciliar, odontológica e de reabilitação.'

# %%
obj['index'][6]='Objeto: Credenciamento de OCS de forma complementar ao\n sistema SAMMED/FUSEX, para prestação de \nserviços de Nuticionista aos usuários.'
# Out:
# C:\Users\efvs\AppData\Local\Temp/ipykernel_16568/777165641.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obj['index'][6]='Objeto: Credenciamento de OCS de forma complementar ao\n sistema SAMMED/FUSEX, para prestação de \nserviços de Nuticionista aos usuários.'

# %%
obj['index'][3]='Objeto: Aquisição de mate-\nrial(is) para  o  CMDO 4ª RM.'
# Out:
# C:\Users\efvs\AppData\Local\Temp/ipykernel_16568/1441401940.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obj['index'][3]='Objeto: Aquisição de mate-\nrial(is) para  o  CMDO 4ª RM.'

# %%
obj['index'][4]='Objeto: Prestação de serviços\n de assistência médico-hospitalar.'
# Out:
# C:\Users\efvs\AppData\Local\Temp/ipykernel_16568/1238568697.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obj['index'][4]='Objeto: Prestação de serviços\n de assistência médico-hospitalar.'

# %%
obj['index'][5]='Objeto: Aquisição de\n material para está om.'
# Out:
# C:\Users\efvs\AppData\Local\Temp/ipykernel_16568/3449814769.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obj['index'][5]='Objeto: Aquisição de\n material para está om.'

# %% [markdown]
# # Investigando se os valores licitados diferem dos valores pagos por item

# %%
# Valor da licitação corresponde a soma de todos os empenhos para à 
# licitação referida

# %%
lic[lic['Número Licitação']==12020]['Valor Licitação'].sum()
# Out:
# 74547627.38

# %%
lic_emp=pd.read_csv(r"C:\Users\efvs\Documents\Residencia Ednael\Dados licitações\202101_EmpenhosRelacionados.csv", encoding='latin-1',sep=';',decimal=',')

# %%
lic_emp[lic_emp['Número Licitação']==12020]['Valor Empenho (R$)'].sum()
# Out:
# 384753.79

# %%
lic_emp[(lic_emp['Número Licitação']==12020) & (lic_emp['Nome UG']=='INST.FED. ESPIRITO SANTO/CAMPUS V.N. DO IMIGR')]['Valor Empenho (R$)'].sum()
# Out:
# 284043.96

# %%
lic[(lic['Número Licitação']==12020) & (lic['Nome UG']=='INST.FED. ESPIRITO SANTO/CAMPUS V.N. DO IMIGR')]['Valor Licitação'].sum()
# Out:
# 5797.4
