# %%
import pandas as pd

# %%
df_lic=pd.read_csv("C:/Users/ednae/Documents/DS/Dados/202101_Licitacao.csv", encoding='latin-1',sep=';',decimal=',')

# %%
df_lic_item=pd.read_csv("C:/Users/ednae/Documents/DS/Dados/202101_ItemLicitacao.csv", encoding='latin-1',sep=';',decimal=',')

# %%
df_lic_emp=pd.read_csv("C:/Users/ednae/Documents/DS/Dados/202101_EmpenhosRelacionados.csv", encoding='latin-1',sep=';',decimal=',')

# %%
df_partic=pd.read_csv("C:/Users/ednae/Documents/DS/Dados/202101_ParticipantesLicita��o.csv", encoding='latin-1',sep=';',decimal=',')

# %%
print(df_lic.shape)
print(df_lic_item.shape)
print(df_lic_emp.shape)
print(df_partic.shape)
# Out:
# (4031, 16)
# (47383, 14)
# (3315, 10)
# (216744, 13)

# %%
df_lic
# Out:
#       Número Licitação  Código UG  \
# 0                12019     154628
# 1                12020     927843
# 2                12020     925538
# 3                12020     925445
# 4                12020     926418
# ...                ...        ...
# 4026         901662020     925302
# 4027         903562019     925302
# 4028         903682019     925302
# 4029         990342020     925302
# 4030         990822020     925302
#
#                                             Nome UG  Código Modalidade Compra  \
# 0           INST.FEDERAL FARROUPILHA CAMPUS JAGUARI                         2
# 1       SECRETARIA DE EST.DE PLANEJ.E ADMINISTRAÇÃO                       -99
# 2              SECRETARIA DE ESTADO DA ADMINSTRAÇÃO                         5
# 3          COMPANHIA DE HABITAÇÃO DO ESTADO DO PARÁ                         5
# 4            COMPANHIA DE SERVIÇOS URBANOS DE NATAL                         5
# ...                                             ...                       ...
# ...

# %%
df_lic_item[df_lic_item['Número Processo']=='00230040002019-37']
# Out:
#      Número Licitação  Código UG                               Nome UG  \
# 313             12020     925538  SECRETARIA DE ESTADO DA ADMINSTRAÇÃO
# 314             12020     925538  SECRETARIA DE ESTADO DA ADMINSTRAÇÃO
# 315             12020     925538  SECRETARIA DE ESTADO DA ADMINSTRAÇÃO
# 316             12020     925538  SECRETARIA DE ESTADO DA ADMINSTRAÇÃO
# 317             12020     925538  SECRETARIA DE ESTADO DA ADMINSTRAÇÃO
# ..                ...        ...                                   ...
# 394             12020     925538  SECRETARIA DE ESTADO DA ADMINSTRAÇÃO
# 395             12020     925538  SECRETARIA DE ESTADO DA ADMINSTRAÇÃO
# 396             12020     925538  SECRETARIA DE ESTADO DA ADMINSTRAÇÃO
# 397             12020     925538  SECRETARIA DE ESTADO DA ADMINSTRAÇÃO
# 398             12020     925538  SECRETARIA DE ESTADO DA ADMINSTRAÇÃO
#
#      Código Modalidade Compra Modalidade Compra    Número Processo  \
# ...
