# %%
import pandas as pd

# %%
df_pas = pd.read_csv("C:/Users/ednae/Documents/DS/2021_Passagem.csv",sep=";", encoding='latin-1',decimal=',')

# %%
df_pag = pd.read_csv("C:/Users/ednae/Documents/DS/2021_Pagamento.csv",sep=";", encoding='latin-1',decimal=',')

# %%
df_techo = pd.read_csv("C:/Users/ednae/Documents/DS/2021_Trecho.csv",sep=";", encoding='latin-1',decimal=',')

# %%
df_viagem = pd.read_csv("C:/Users/ednae/Documents/DS/2021_Viagem.csv",sep=";", encoding='latin-1',decimal=',')

# %%
df_pas[df_pas['Identificador do processo de viagem']==16889781]
# Out:
#    Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                             16889781                 000120/20
# 1                             16889781                 000120/20
#
#   Meio de transporte País - Origem ida UF - Origem ida Cidade - Origem ida  \
# 0              Aéreo            Brasil           Ceará           Fortaleza
# 1              Aéreo            Brasil         Sergipe             Aracaju
#
#   País - Destino ida UF - Destino ida Cidade - Destino ida  \
# 0             Brasil          Sergipe              Aracaju
# 1             Brasil            Ceará            Fortaleza
#
#   País - Origem volta UF - Origem volta Cidade - Origem volta  \
# 0      Sem Informação    Sem Informação        Sem Informação
# 1      Sem Informação    Sem Informação        Sem Informação
#
#   Pais - Destino volta UF - Destino volta Cidade - Destino volta  \
# 0       Sem Informação     Sem Informação         Sem Informação
# ...

# %%
df_pag[df_pag['Identificador do processo de viagem']==16889781]
# Out:
#    Identificador do processo de viagem Número da Proposta (PCDP)  \
# 1                             16889781                 000120/20
# 2                             16889781                 000120/20
# 3                             16889781                 000120/20
# 4                             16889781                 000120/20
#
#    Código do órgão superior  Nome do órgão superior  Codigo do órgão pagador  \
# 1                     26000  Ministério da Educação                    26281
# 2                     26000  Ministério da Educação                    26281
# 3                     26000  Ministério da Educação                    26281
# 4                     26000  Ministério da Educação                    26281
#
#                       Nome do órgao pagador  \
# 1  Fundação Universidade Federal de Sergipe
# 2  Fundação Universidade Federal de Sergipe
# 3  Fundação Universidade Federal de Sergipe
# 4  Fundação Universidade Federal de Sergipe
#
# ...

# %%
df_viagem[df_viagem['Identificador do processo de viagem']==16889781]
# Out:
#    Identificador do processo de viagem Número da Proposta (PCDP)  \
# 1                             16889781                 000120/20
#
#         Situação Viagem Urgente Justificativa Urgência Viagem  \
# 1  Não realizada            NÃO                Sem informação
#
#    Código do órgão superior  Nome do órgão superior  Código órgão solicitante  \
# 1                     26000  Ministério da Educação                     26281
#
#                      Nome órgão solicitante    CPF viajante  ...  \
# 1  Fundação Universidade Federal de Sergipe  ***.157.645-**  ...
#
#                          Cargo   Função Descrição Função  \
# 1  ASSISTENTE EM ADMINISTRAçãO  FG-0001          FG-0001
#
#   Período - Data de início Período - Data de fim      Destinos  \
# 1               11/05/2021            16/05/2021  Fortaleza/CE
#
#                                               Motivo Valor diárias  \
# 1  Participação no XXI Congresso Nacional de Secr...           0.0
#
# ...

# %%
print(df_pas.shape)
print(df_pag.shape)
print(df_techo.shape)
print(df_viagem.shape)
# Out:
# (108672, 19)
# (481971, 10)
# (611675, 14)
# (297459, 21)

# %%
df_pas[(df_pas['UF - Origem ida']=='São Paulo') & (df_pas['UF - Destino ida']=='Rio de Janeiro')]['Meio de transporte'].value_counts()
# Out:
# Aéreo         978
# Rodoviário      7
# Name: Meio de transporte, dtype: int64

# %%
df_pas[(df_pas['UF - Origem ida']=='São Paulo') & (df_pas['UF - Destino ida']=='Rio de Janeiro')]['Valor da passagem'].value_counts()
# Out:
# 479.24     22
# 282.93     17
# 0.00       15
# 200.55     15
# 683.95     12
#            ..
# 735.96      1
# 611.96      1
# 672.62      1
# 685.60      1
# 1271.55     1
# Name: Valor da passagem, Length: 558, dtype: int64

# %%
df_pas[(df_pas['UF - Origem ida']=='São Paulo') & (df_pas['UF - Destino ida']=='Distrito Federal')]['Valor da passagem'].value_counts()
# Out:
# 419.42     53
# 1657.96    49
# 0.00       47
# 743.56     46
# 867.42     44
#            ..
# 979.23      1
# 347.35      1
# 343.44      1
# 805.47      1
# 1564.96     1
# Name: Valor da passagem, Length: 2188, dtype: int64

# %%
df_pas['Valor da passagem'].sum()
# Out:
# 116279636.13999999

# %%
df_pas['Data da emissão/compra'].value_counts()
# Out:
# 27/08/2021    1060
# 06/08/2021    1032
# 30/07/2021    1027
# 08/10/2021    1017
# 23/09/2021     950
#               ...
# 18/11/2020       1
# 21/10/2020       1
# 25/09/2020       1
# 11/09/2020       1
# 07/11/2021       1
# Name: Data da emissão/compra, Length: 346, dtype: int64

# %%
df_pas
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                                  16889781                 000120/20
# 1                                  16889781                 000120/20
# 2                                  16910306                 000076/20
# 3                                  16910306                 000076/20
# 4                                  16911615                 000139/20
# ...                                     ...                       ...
# 108667                           2021000238            Sem informação
# 108668                           2021000238            Sem informação
# 108669                           2021000242            Sem informação
# 108670                           2021000258            Sem informação
# 108671                           2021000258            Sem informação
#
#        Meio de transporte País - Origem ida    UF - Origem ida  \
# ...

# %%
df_pas[df_pas['Data da emissão/compra']=='27/08/2021']["País - Destino ida"].value_counts()
# Out:
# Brasil                       1033
# Rússia                          6
# Estados Unidos da América       3
# Cabo Verde                      3
# Marrocos                        3
# Bolívia                         3
# Reino Unido                     3
# Espanha                         2
# Suécia                          2
# França                          1
# Emirados Árabes                 1
# Name: País - Destino ida, dtype: int64

# %%
df_viagem[df_viagem['Período - Data de início']=='27/08/2021']['Motivo'].value_counts()
# Out:
# Informação protegida por sigilo nos termos da legislação vigente                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   132
# ...
